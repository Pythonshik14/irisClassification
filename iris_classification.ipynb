# %%
# подключение colab.drive
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import svm

# %%
path = "/content/gdrive/My Drive/Home_works/iris.csv"
data = pd.read_csv(path)

# %%
params = data.drop("name", axis=1).corr().columns
params
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
x_train, x_test, y_train, y_test = train_test_split(data[params], data['name'], test_size=0.2, random_state=0)

# %%
gamma = [0.001, 0.01, 0.005, 0.02]
C = [1, 10, 50, 100, 200, 500, 1000]
parameters1 = {"gamma":gamma, 
               "C":C}

# %%
model = svm.SVC(**parameters1)
grid = GridSearchCV(model, parameters1, cv=4)
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=4, error_score=nan,
#              estimator=SVC(C=[1, 10, 50, 100, 200, 500, 1000], break_ties=False,
#                            cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma=[0.001, 0.01, 0.005, 0.02], kernel='rbf',
#                            max_iter=-1, probability=False, random_state=None,
#                            shrinking=True, tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 10, 50, 100, 200, 500, 1000],
#                          'gamma': [0.001, 0.01, 0.005, 0.02]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
pred = grid.predict(x_test)

# %%
list(pred) == y_test
# Out:
# 114    True
# 62     True
# 33     True
# 107    True
# 7      True
# 100    True
# 40     True
# 86     True
# 76     True
# 71     True
# 134    True
# 51     True
# 73     True
# 54     True
# 63     True
# 37     True
# 78     True
# 90     True
# 45     True
# 16     True
# 121    True
# 66     True
# 24     True
# 8      True
# 126    True
# 22     True
# 44     True
# 97     True
# 93     True
# 26     True
# Name: name, dtype: bool
